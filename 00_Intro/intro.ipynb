# %% [markdown]
# # "pty-co-SAXSNN"
#
# ### CNN enhanced deconvolution of ptychographic coherent SAXS data

# %% [markdown]
# ### Workflow
#
# - Load conda (python) environment (```SETUP.md```)
#
# - Required files: probe, lattice
#
# **(01)** Data generation
#
# **(02)** Preprocess data before input into NN training scheme
#
# **(03)** Train NN on data, save NN with lowest validation loss, test on other simulated data
#
# **(04)** Inference on experimental data
#
# **(05)** Postprocessing the NN output data
#
# **(06)** Tomographic characterization
#
# **(07)** Calculating performance metrics of network
#
# **(08)** Batch processing for pty-co-SAXSNN
#
# **(09)** Clathrate simulations (Triangular Bipyramid Particles)
